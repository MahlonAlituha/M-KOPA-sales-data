# %%
pip install pandas
# Out:
# Collecting pandas
#   Using cached pandas-2.0.3-cp311-cp311-win_amd64.whl (10.6 MB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\appdata\roaming\python\python311\site-packages (from pandas) (2.8.2)
# Collecting pytz>=2020.1
#   Using cached pytz-2023.3-py2.py3-none-any.whl (502 kB)
# Collecting tzdata>=2022.1
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# Collecting numpy>=1.21.0
#   Downloading numpy-1.25.1-cp311-cp311-win_amd64.whl (15.0 MB)
#      ---------------------------------------- 15.0/15.0 MB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-1.25.1 pandas-2.0.3 pytz-2023.3 tzdata-2023.3
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script f2py.exe is installed in 'c:\Users\DELL\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install openpyxl
# Out:
# Collecting openpyxlNote: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#      ------------------------------------ 250.0/250.0 kB 184.8 kB/s eta 0:00:00
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.2

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.7.2-cp311-cp311-win_amd64.whl (7.5 MB)
#      ---------------------------------------- 7.5/7.5 MB 2.4 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.1.0-cp311-cp311-win_amd64.whl (470 kB)
#      -------------------------------------- 470.9/470.9 kB 2.5 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.40.0-cp311-cp311-win_amd64.whl (1.9 MB)
#      ---------------------------------------- 1.9/1.9 MB 3.4 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp311-cp311-win_amd64.whl (55 kB)
#      -------------------------------------- 55.4/55.4 kB 240.2 kB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.25.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\appdata\roaming\python\python311\site-packages (from matplotlib) (23.1)
# Collecting pillow>=6.2.0
#   Downloading Pillow-10.0.0-cp311-cp311-win_amd64.whl (2.5 MB)
#      ---------------------------------------- 2.5/2.5 MB 2.6 MB/s eta 0:00:00
# Collecting pyparsing<3.1,>=2.3.1
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      ---------------------------------------- 98.3/98.3 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\appdata\roaming\python\python311\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.1.0 cycler-0.11.0 fonttools-4.40.0 kiwisolver-1.4.4 matplotlib-3.7.2 pillow-10.0.0 pyparsing-3.0.9
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'c:\Users\DELL\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# Read the Excel file into a pandas DataFrame
df = pd.read_excel('Sales and Payment Plans Data_Technical Exercise Commercial Sales Analyst.xlsx')
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df.head()
# Out:
#   Created At Date                   Payment Plan Name Product Sub Category  \
# 0      2023-04-20             MK 600 24" TV v21 Staff           M-KOPA 600
# 1      2023-04-20            MK 6000C 32" TV v3 Staff          M-KOPA 6000
# 2      2023-02-08   MK 600 24" TV v24 Non-Locking HRA           M-KOPA 600
# 3      2023-02-08                        MK 6 v11 HRA             M-KOPA 6
# 4      2023-02-08  MK 6000 32" TV v24 Non Locking HRA          M-KOPA 6000
#
#   Product Type Currency Name  Product Price  Deposit  Daily Top Up  \
# 0     Solar TV           KES          64199   2999.0          90.0
# 1     Solar TV           KES          86499   6499.0         100.0
# 2     Solar TV           KES          81999   5999.0         100.0
# 3       Lights           KES          23999    999.0          50.0
# 4     Solar TV           KES         116199   6999.0         130.0
#
#    Loan Duration  Total Top Ups   Brand Masterbrand        Model    Plan Type  \
# 0          680.0        61200.0  M-KOPA       Solar   M-KOPA 600  Acquisition
# 1          800.0        80000.0  M-KOPA       Solar  M-KOPA 6000  Acquisition
# 2          760.0        76000.0  M-KOPA       Solar   M-KOPA 600  Acquisition
# 3          460.0        23000.0  M-KOPA       Solar     M-KOPA 6  Acquisition
# 4          840.0       109200.0  M-KOPA       Solar  M-KOPA 6000  Acquisition
#
#   Product Category   Variant  Mart Payment Plan ID Payment Plan Status
# 0            MK TV    24" TV                  4319              Active
# 1            MK TV    32" TV                  4318                 New
# 2            MK TV    24" TV                  4077              Closed
# 3       MK Classic  4 lights                  4088              Active
# 4            MK TV    32" TV                  4102              Closed

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 488 entries, 0 to 487
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Created At Date       488 non-null    datetime64[ns]
#  1   Payment Plan Name     488 non-null    object
#  2   Product Sub Category  488 non-null    object
#  3   Product Type          488 non-null    object
#  4   Currency Name         488 non-null    object
#  5   Product Price         488 non-null    int64
#  6   Deposit               477 non-null    float64
#  7   Daily Top Up          477 non-null    float64
#  8   Loan Duration         477 non-null    float64
#  9   Total Top Ups         477 non-null    float64
#  10  Brand                 488 non-null    object
#  11  Masterbrand           488 non-null    object
#  12  Model                 484 non-null    object
#  13  Plan Type             488 non-null    object
#  14  Product Category      488 non-null    object
#  15  Variant               487 non-null    object
#  16  Mart Payment Plan ID  488 non-null    int64
#  17  Payment Plan Status   488 non-null    object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(11)
# memory usage: 68.8+ KB

# %%
df1 = pd.read_excel('Sales and Payment Plans Data_Technical Exercise Commercial Sales Analyst.xlsx', sheet_name=1)

# %%
df1.head()
# Out:
#              Model Local Sold At Month            Payment Plan Name  Sales
# 0  M-KOPA Copia TV             2023-05   MK Copia TV 32" Upgrade v9      2
# 1  M-KOPA Copia TV             2023-05  MK Copia TV 32" Upgrade v10     18
# 2  M-KOPA Copia TV             2023-05   MK Copia TV 32" Upgrade v6      1
# 3  M-KOPA Copia TV             2023-04   MK Copia TV 32" Upgrade v2      1
# 4  M-KOPA Copia TV             2023-04  MK Copia TV 32" Upgrade v10     35

# %%
salesdf = pd.merge(df, df1, on='Payment Plan Name')

# %%
salesdf["Sales"].tail()
# Out:
# 152    11
# 153     7
# 154    48
# 155    36
# 156     5
# Name: Sales, dtype: int64

# %%
# Convert the date column to datetime type
salesdf['Local Sold At Month'] = pd.to_datetime(salesdf['Local Sold At Month'])

# Extract the month from the date
salesdf['Month'] = salesdf['Local Sold At Month'].dt.month

# %%
salesdf.head(2)
# Out:
#   Created At Date           Payment Plan Name Product Sub Category  \
# 0      2023-02-08  MK 6000 32" TV (BB) v2 HRA          M-KOPA 6000
# 1      2023-02-08  MK 6000 32" TV (BB) v2 HRA          M-KOPA 6000
#
#   Product Type Currency Name  Product Price  Deposit  Daily Top Up  \
# 0     Solar TV           KES         129299   7499.0         145.0
# 1     Solar TV           KES         129299   7499.0         145.0
#
#    Loan Duration  Total Top Ups  ...      Model_x    Plan Type  \
# 0          840.0       121800.0  ...  M-KOPA 6000  Acquisition
# 1          840.0       121800.0  ...  M-KOPA 6000  Acquisition
#
#   Product Category Variant Mart Payment Plan ID Payment Plan Status  \
# 0            MK TV  32" TV                 4096              Active
# 1            MK TV  32" TV                 4096              Active
#
#        Model_y Local Sold At Month Sales Month
# 0  M-KOPA 6000          2023-05-01     1     5
# 1  M-KOPA 6000          2023-03-01     2     3
#
# [2 rows x 22 columns]

# %%
monthly_sales = salesdf.groupby(['Month', 'Payment Plan Name'])['Sales'].sum()

monthly_sales
# Out:
# Month  Payment Plan Name
# 1      MK +600 24" TV v27                       16
#        MK +6000 32" TV (BB) v2                   1
#        MK +6000 32" TV v23                     257
#        MK 6 v10                                 27
#        MK 6 v4 Staff                             1
#                                               ...
# 12     MK 6000 (32"Backup TV) v9                 1
#        MK 6000 32" TV (BB) v1                  411
#        MK 6000 32" TV v2 Staff                   9
#        MK 6000 32" TV v22                      718
#        MK 60K (80W Panel) 32"TV & Fridge v4      1
# Name: Sales, Length: 157, dtype: int64

# %%
# Reset index to turn the groupby result into a DataFrame
monthly_sales = monthly_sales.reset_index()

# %%
monthly_sales
# Out:
#      Month                     Payment Plan Name  Sales
# 0        1                    MK +600 24" TV v27     16
# 1        1               MK +6000 32" TV (BB) v2      1
# 2        1                   MK +6000 32" TV v23    257
# 3        1                              MK 6 v10     27
# 4        1                         MK 6 v4 Staff      1
# ..     ...                                   ...    ...
# 152     12             MK 6000 (32"Backup TV) v9      1
# 153     12                MK 6000 32" TV (BB) v1    411
# 154     12               MK 6000 32" TV v2 Staff      9
# 155     12                    MK 6000 32" TV v22    718
# 156     12  MK 60K (80W Panel) 32"TV & Fridge v4      1
#
# [157 rows x 3 columns]

# %%
# Find the index of the maximum sales value for each month
max_sales_indices = monthly_sales.groupby('Month')['Sales'].idxmax()

# Extract the payment plan with the highest sales for each month
payment_plan_highest_sales = monthly_sales.loc[max_sales_indices, ['Month', 'Payment Plan Name', 'Sales']]

# %%
payment_plan_highest_sales
# Out:
#      Month   Payment Plan Name  Sales
# 10       1  MK 6000 32" TV v22   1163
# 20       2  MK 6000 32" TV v22    630
# 27       3   MK 600 24" TV v20    599
# 37       4   MK 600 24" TV v20    615
# 43       5   MK 600 24" TV v20    124
# 58       6  MK 6000 32" TV v20   1234
# 76       7  MK 6000 32" TV v21   1279
# 95       8  MK 6000 32" TV v21   2109
# 111      9  MK 6000 32" TV v22   1097
# 121     10   MK 600 24" TV v18    649
# 135     11   MK 600 24" TV v18    628
# 151     12   MK 600 24" TV v20   1608

# %%
pip install tabulate
# Out:
# Collecting tabulate
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Installing collected packages: tabulate
# Successfully installed tabulate-0.9.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script tabulate.exe is installed in 'c:\Users\DELL\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
payment_plan_highest_sales_table = payment_plan_highest_sales.to_markdown()

# %%
payment_plan_highest_sales
# Out:
#             Payment Plan Name  Sales
# Month
# January    MK 6000 32" TV v22   1163
# February   MK 6000 32" TV v22    630
# March       MK 600 24" TV v20    599
# April       MK 600 24" TV v20    615
# May         MK 600 24" TV v20    124
# June       MK 6000 32" TV v20   1234
# July       MK 6000 32" TV v21   1279
# August     MK 6000 32" TV v21   2109
# September  MK 6000 32" TV v22   1097
# October     MK 600 24" TV v18    649
# November    MK 600 24" TV v18    628
# December    MK 600 24" TV v20   1608

# %%
markdown = payment_plan_highest_sales.to_markdown()

# %%
print(markdown)
# Out:
# | Month     | Payment Plan Name   |   Sales |
# |:----------|:--------------------|--------:|
# | January   | MK 6000 32" TV v22  |    1163 |
# | February  | MK 6000 32" TV v22  |     630 |
# | March     | MK 600 24" TV v20   |     599 |
# | April     | MK 600 24" TV v20   |     615 |
# | May       | MK 600 24" TV v20   |     124 |
# | June      | MK 6000 32" TV v20  |    1234 |
# | July      | MK 6000 32" TV v21  |    1279 |
# | August    | MK 6000 32" TV v21  |    2109 |
# | September | MK 6000 32" TV v22  |    1097 |
# | October   | MK 600 24" TV v18   |     649 |
# | November  | MK 600 24" TV v18   |     628 |
# | December  | MK 600 24" TV v20   |    1608 |

# %%
import calendar

# Assuming you have a DataFrame called 'payment_plan_highest_sales' with columns 'Month', 'Payment Plan', and 'Sales'

# Create a dictionary to map month numbers to month names
month_names = dict(enumerate(calendar.month_name))

# Replace the month numbers with month names
payment_plan_highest_sales['Month'] = payment_plan_highest_sales['Month'].map(month_names)

# %%
# Set the 'Month' column as the index
payment_plan_highest_sales.set_index('Month', inplace=True)

# %%
payment_plan_highest_sales
# Out:
#             Payment Plan Name  Sales
# Month
# January    MK 6000 32" TV v22   1163
# February   MK 6000 32" TV v22    630
# March       MK 600 24" TV v20    599
# April       MK 600 24" TV v20    615
# May         MK 600 24" TV v20    124
# June       MK 6000 32" TV v20   1234
# July       MK 6000 32" TV v21   1279
# August     MK 6000 32" TV v21   2109
# September  MK 6000 32" TV v22   1097
# October     MK 600 24" TV v18    649
# November    MK 600 24" TV v18    628
# December    MK 600 24" TV v20   1608

# %%
# Save the DataFrame as a CSV file
payment_plan_highest_sales.to_csv('payment_plan_highest_sales.csv', index=True)

# %% [markdown]
# payment plan with highest sales per month

# %%
salesdf.head(3)
# Out:
#   Created At Date           Payment Plan Name Product Sub Category  \
# 0      2023-02-08  MK 6000 32" TV (BB) v2 HRA          M-KOPA 6000
# 1      2023-02-08  MK 6000 32" TV (BB) v2 HRA          M-KOPA 6000
# 2      2023-02-08       MK 600 24" TV v21 HRA           M-KOPA 600
#
#   Product Type Currency Name  Product Price  Deposit  Daily Top Up  \
# 0     Solar TV           KES         129299   7499.0         145.0
# 1     Solar TV           KES         129299   7499.0         145.0
# 2     Solar TV           KES          74999   4999.0         100.0
#
#    Loan Duration  Total Top Ups  ...      Model_x    Plan Type  \
# 0          840.0       121800.0  ...  M-KOPA 6000  Acquisition
# 1          840.0       121800.0  ...  M-KOPA 6000  Acquisition
# 2          700.0        70000.0  ...   M-KOPA 600  Acquisition
#
#   Product Category Variant Mart Payment Plan ID Payment Plan Status  \
# 0            MK TV  32" TV                 4096              Active
# 1            MK TV  32" TV                 4096              Active
# 2            MK TV  24" TV                 4083              Active
#
#        Model_y Local Sold At Month Sales Month
# 0  M-KOPA 6000          2023-05-01     1     5
# 1  M-KOPA 6000          2023-03-01     2     3
# 2   M-KOPA 600          2023-05-01    43     5
#
# [3 rows x 22 columns]

# %%
salesdf['Revenue'] = salesdf['Product Price'] * salesdf['Sales']
salesdf.head()
# Out:
#   Created At Date           Payment Plan Name Product Sub Category  \
# 0      2023-02-08  MK 6000 32" TV (BB) v2 HRA          M-KOPA 6000
# 1      2023-02-08  MK 6000 32" TV (BB) v2 HRA          M-KOPA 6000
# 2      2023-02-08       MK 600 24" TV v21 HRA           M-KOPA 600
# 3      2023-02-08       MK 600 24" TV v21 HRA           M-KOPA 600
# 4      2023-02-08       MK 600 24" TV v21 HRA           M-KOPA 600
#
#   Product Type Currency Name  Product Price  Deposit  Daily Top Up  \
# 0     Solar TV           KES         129299   7499.0         145.0
# 1     Solar TV           KES         129299   7499.0         145.0
# 2     Solar TV           KES          74999   4999.0         100.0
# 3     Solar TV           KES          74999   4999.0         100.0
# 4     Solar TV           KES          74999   4999.0         100.0
#
#    Loan Duration  Total Top Ups  ...    Plan Type Product Category Variant  \
# 0          840.0       121800.0  ...  Acquisition            MK TV  32" TV
# 1          840.0       121800.0  ...  Acquisition            MK TV  32" TV
# 2          700.0        70000.0  ...  Acquisition            MK TV  24" TV
# 3          700.0        70000.0  ...  Acquisition            MK TV  24" TV
# 4          700.0        70000.0  ...  Acquisition            MK TV  24" TV
#
#   Mart Payment Plan ID Payment Plan Status      Model_y  Local Sold At Month  \
# 0                 4096              Active  M-KOPA 6000           2023-05-01
# 1                 4096              Active  M-KOPA 6000           2023-03-01
# 2                 4083              Active   M-KOPA 600           2023-05-01
# 3                 4083              Active   M-KOPA 600           2023-04-01
# 4                 4083              Active   M-KOPA 600           2023-03-01
#
#   Sales Month   Revenue
# 0     1     5    129299
# 1     2     3    258598
# 2    43     5   3224957
# 3   230     4  17249770
# 4   215     3  16124785
#
# [5 rows x 23 columns]

# %%
# Group the data by "Product Sub Category" and calculate the total revenue for each group
revenue_by_subcategory = salesdf.groupby('Product Sub Category')['Revenue'].sum()
revenue_by_subcategory=revenue_by_subcategory.sort_values(ascending=False)
revenue_by_subcategory.to_csv('revenue_by_subcategory.csv', index=False)

# %%
# Sort the revenue values in descending order
revenue_by_subcategory = revenue_by_subcategory.sort_values(ascending=False)
# Plot the revenue by subcategory using a bar chart
revenue_by_subcategory.plot(kind='bar')

# Add labels and title
plt.xlabel('Product Sub Category')
plt.ylabel('Revenue')
plt.title('Revenue by Subcategory')

# Show the plot
plt.show()

# %%
# Drop the rows with the specified index
salesdf = salesdf.drop(index=126)
salesdf = salesdf.drop(index=127)

# %%
salesdf.head(2)
# Out:
#   Created At Date           Payment Plan Name Product Sub Category  \
# 0      2023-02-08  MK 6000 32" TV (BB) v2 HRA          M-KOPA 6000
# 1      2023-02-08  MK 6000 32" TV (BB) v2 HRA          M-KOPA 6000
#
#   Product Type Currency Name  Product Price  Deposit  Daily Top Up  \
# 0     Solar TV           KES         129299   7499.0         145.0
# 1     Solar TV           KES         129299   7499.0         145.0
#
#    Loan Duration  Total Top Ups  ...    Plan Type Product Category Variant  \
# 0          840.0       121800.0  ...  Acquisition            MK TV  32" TV
# 1          840.0       121800.0  ...  Acquisition            MK TV  32" TV
#
#   Mart Payment Plan ID Payment Plan Status      Model_y  Local Sold At Month  \
# 0                 4096              Active  M-KOPA 6000           2023-05-01
# 1                 4096              Active  M-KOPA 6000           2023-03-01
#
#   Sales Month Revenue
# 0     1     5  129299
# 1     2     3  258598
#
# [2 rows x 23 columns]

# %%
salesdf.to_csv('salesdf.csv', index=False)

# %%
# Calculate the average top-up amount for each product type
average_top_up = salesdf.groupby('Product Type')['Daily Top Up'].mean()

average_top_up.to_csv('average_top_up.csv', index=False)

# %%
print(average_top_up)
# Out:
# Product Type
# Grid TV     126.250000
# Lights       47.666667
# Solar TV    120.000000
# Name: Daily Top Up, dtype: float64

# %%
av = average_top_up.to_markdown()
print(av)
# Out:
# | Product Type   |   Daily Top Up |
# |:---------------|---------------:|
# | Grid TV        |       126.25   |
# | Lights         |        47.6667 |
# | Solar TV       |       120      |

# %%
salesdf["Model_x"].unique()
# Out:
# array(['M-KOPA 6000', 'M-KOPA 600', 'M-KOPA +6000', 'M-KOPA +600',
#        'M-KOPA 6', 'M-KOPA 60000', 'M-KOPA 6000 Grid', 'M-KOPA 600 Zuku'],
#       dtype=object)

# %%
salesdf["Model_y"].unique()
# Out:
# array(['M-KOPA 6000', 'M-KOPA 600', 'M-KOPA +6000', 'M-KOPA +600',
#        'M-KOPA 6', 'M-KOPA 60000', 'M-KOPA 6000 Grid', 'M-KOPA 600 Zuku'],
#       dtype=object)

# %%
# Check if the two columns are equal
columns_equal = salesdf['Model_x'].equals(salesdf['Model_y'])

# Print the result
if columns_equal:
    print("Are equal.")
else:
    print("Are not equal.")
# Out:
# Are equal.

# %%
salesdf.head(2)
# Out:
#   Created At Date           Payment Plan Name Product Sub Category  \
# 0      2023-02-08  MK 6000 32" TV (BB) v2 HRA          M-KOPA 6000
# 1      2023-02-08  MK 6000 32" TV (BB) v2 HRA          M-KOPA 6000
#
#   Product Type Currency Name  Product Price  Deposit  Daily Top Up  \
# 0     Solar TV           KES         129299   7499.0         145.0
# 1     Solar TV           KES         129299   7499.0         145.0
#
#    Loan Duration  Total Top Ups  ...    Plan Type Product Category Variant  \
# 0          840.0       121800.0  ...  Acquisition            MK TV  32" TV
# 1          840.0       121800.0  ...  Acquisition            MK TV  32" TV
#
#   Mart Payment Plan ID Payment Plan Status      Model_y  Local Sold At Month  \
# 0                 4096              Active  M-KOPA 6000           2023-05-01
# 1                 4096              Active  M-KOPA 6000           2023-03-01
#
#   Sales Month Revenue
# 0     1     5  129299
# 1     2     3  258598
#
# [2 rows x 23 columns]

# %%
pip install seaborn
# Out:
# Collecting seabornNote: you may need to restart the kernel to use updated packages.
#
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      ------------------------------------ 293.3/293.3 kB 335.8 kB/s eta 0:00:00
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (1.25.1)
# Requirement already satisfied: pandas>=0.25 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.2
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have a DataFrame called 'df' with columns 'Model' and 'Sales' 

# Convert the date column to datetime type, if needed
salesdf['Local Sold At Month'] = pd.to_datetime(salesdf['Local Sold At Month'])
plt.figure(figsize=(10, 6))
# Plot the sales trend over time with different trend lines for each model
sns.lineplot(x='Local Sold At Month', y='Sales', hue='Model_x', data=salesdf, ci=None)

# Add a title and labels
plt.title('Sales Trend of Different Models')
plt.xlabel('Date')
plt.ylabel('Sales')

# Show the plot
plt.show();
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10352\2132843289.py:10: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='Local Sold At Month', y='Sales', hue='Model_x', data=salesdf, ci=None)

# %%
# Sort the DataFrame by 'Sales' column in ascending order
sorted_df = salesdf.sort_values('Sales', ascending=True)

# %%
sorted_df.tail()
# Out:
#    Created At Date   Payment Plan Name Product Sub Category Product Type  \
# 57      2022-08-29  MK 6000 32" TV v22          M-KOPA 6000     Solar TV
# 98      2022-02-01  MK 6000 32" TV v20          M-KOPA 6000     Solar TV
# 65      2022-07-01  MK 6000 32" TV v21          M-KOPA 6000     Solar TV
# 18      2022-11-18   MK 600 24" TV v20           M-KOPA 600     Solar TV
# 64      2022-07-01  MK 6000 32" TV v21          M-KOPA 6000     Solar TV
#
#    Currency Name  Product Price  Deposit  Daily Top Up  Loan Duration  \
# 57           KES         116199   6999.0         130.0          840.0
# 98           KES          88999   7999.0         135.0          600.0
# 65           KES         108399   6999.0         130.0          780.0
# 18           KES          74999   4999.0         100.0          700.0
# 64           KES         108399   6999.0         130.0          780.0
#
#     Total Top Ups  ...    Plan Type Product Category Variant  \
# 57       109200.0  ...  Acquisition            MK TV  32" TV
# 98        81000.0  ...  Acquisition            MK TV  32" TV
# 65       101400.0  ...  Acquisition            MK TV  32" TV
# 18        70000.0  ...  Acquisition            MK TV  24" TV
# 64       101400.0  ...  Acquisition            MK TV  32" TV
#
#    Mart Payment Plan ID Payment Plan Status      Model_y  Local Sold At Month  \
# 57                 3309              Active  M-KOPA 6000           2023-01-01
# 98                 2623              Closed  M-KOPA 6000           2022-06-01
# 65                 3128              Closed  M-KOPA 6000           2022-07-01
# 18                 3763              Active   M-KOPA 600           2022-12-01
# 64                 3128              Closed  M-KOPA 6000           2022-08-01
#
#    Sales Month    Revenue
# 57  1163     1  135139437
# 98  1234     6  109824766
# 65  1279     7  138642321
# 18  1608    12  120598392
# 64  2109     8  228613491
#
# [5 rows x 23 columns]

# %%
# Get all the unique entries in the 'Column' column
unique_entries = salesdf['Masterbrand'].unique()

# Print the unique entries
print(unique_entries)
# Out:
# ['Solar']

# %%
import calendar
# Group the data by the month and calculate the total revenue for each month
monthly_revenue = salesdf.groupby("Local Sold At Month")['Revenue'].sum()

# Reset the index to make 'Date' a column
monthly_revenue = monthly_revenue.reset_index()
# Replace the month numbers with month names
monthly_revenue['Local Sold At Month'] = monthly_revenue['Local Sold At Month'].dt.month.map(lambda x: calendar.month_name[x])
monthly_revenue['Local Sold At Month'] = pd.Categorical(monthly_revenue['Local Sold At Month'], categories=calendar.month_name[1:], ordered=True)
# Plot the trendline of the monthly total revenue
plt.figure(figsize=(12, 6))
sns.lineplot(x='Local Sold At Month', y='Revenue', data=monthly_revenue)

# Add a title and labels
plt.title('Monthly Revenue Trend')
plt.xlabel('Month')
plt.ylabel('Total Revenue')

# Show the plot
plt.show()

# %%
salesdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 155 entries, 0 to 156
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Created At Date       155 non-null    datetime64[ns]
#  1   Payment Plan Name     155 non-null    object
#  2   Product Sub Category  155 non-null    object
#  3   Product Type          155 non-null    object
#  4   Currency Name         155 non-null    object
#  5   Product Price         155 non-null    int64
#  6   Deposit               155 non-null    float64
#  7   Daily Top Up          155 non-null    float64
#  8   Loan Duration         155 non-null    float64
#  9   Total Top Ups         155 non-null    float64
#  10  Brand                 155 non-null    object
#  11  Masterbrand           155 non-null    object
#  12  Model_x               155 non-null    object
#  13  Plan Type             155 non-null    object
#  14  Product Category      155 non-null    object
#  15  Variant               149 non-null    object
#  16  Mart Payment Plan ID  155 non-null    int64
#  17  Payment Plan Status   155 non-null    object
#  18  Model_y               155 non-null    object
#  19  Local Sold At Month   155 non-null    datetime64[ns]
#  20  Sales                 155 non-null    int64
#  21  Month                 155 non-null    int32
#  22  Revenue               155 non-null    int64
# dtypes: datetime64[ns](2), float64(4), int32(1), int64(4), object(12)
# memory usage: 28.5+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 488 entries, 0 to 487
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Created At Date       488 non-null    datetime64[ns]
#  1   Payment Plan Name     488 non-null    object
#  2   Product Sub Category  488 non-null    object
#  3   Product Type          488 non-null    object
#  4   Currency Name         488 non-null    object
#  5   Product Price         488 non-null    int64
#  6   Deposit               477 non-null    float64
#  7   Daily Top Up          477 non-null    float64
#  8   Loan Duration         477 non-null    float64
#  9   Total Top Ups         477 non-null    float64
#  10  Brand                 488 non-null    object
#  11  Masterbrand           488 non-null    object
#  12  Model                 484 non-null    object
#  13  Plan Type             488 non-null    object
#  14  Product Category      488 non-null    object
#  15  Variant               487 non-null    object
#  16  Mart Payment Plan ID  488 non-null    int64
#  17  Payment Plan Status   488 non-null    object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(11)
# memory usage: 68.8+ KB
